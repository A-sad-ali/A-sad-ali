# %% [markdown]
# <a href="https://colab.research.google.com/github/A-sad-ali/A-sad-ali/blob/main/notebookasd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Covid-19 Pre-existing Medical Condition Analysis using Plotly

# %% [markdown]
# #  Importing all the necessary libraries

# %%
import pandas as pd       #Data analysis and Manipulation
import plotly.express as px    #Data Visualization (one line of code for one graph)
import matplotlib.pyplot as plt   #Data Visualization for WordCloud
#from wordcloud import WordCloud   #Wordcloud Text Visualization

# %%
import plotly.io as pio
pio.renderers.default = 'colab'     # To initialize plotly (default mode of plotly if OFF as it consumes a lot of space)

# %% [markdown]
# ## Importing the dataset and Visualizing it (Dataset 1 : Worldometer dataset)

# %%
from google.colab import files
files.upload()

# %%
df = pd.read_csv("covid_worldometer_data.csv")

# %%
df
# Out:
#      S.no            Country  TotalCases TotalDeaths Total Recovered  \
# 0       1                USA  23,848,410     397,994      14,112,119
# 1       2              India  10,528,508     151,954      10,162,738
# 2       3             Brazil   8,326,115     207,160       7,339,703
# 3       4             Russia   3,495,816      63,940       2,882,044
# 4       5                 UK   3,260,258      86,015       1,406,967
# ..    ...                ...         ...         ...             ...
# 216   217  Wallis and Futuna           4                           1
# 217   218              Samoa           2                           2
# 218   219         Micronesia           1                         NaN
# 219   220            Vanuatu           1                           1
# 220   221              China      87,988       4,635          82,352
#
#     Active cases Totalcases/1M TotalDeath/1M iso_alpha
# 0      9,338,297        71,822         1,199       USA
# ...

# %%
px.bar(df.head(15), x="Country", y="TotalCases", color = "Country")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(df.head(15), x="Country", y="TotalDeaths", color = "Country")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.columns
# Out:
# Index(['S.no', 'Country', 'TotalCases', 'TotalDeaths', 'Total Recovered',
#        'Active cases', 'Totalcases/1M', 'TotalDeath/1M', 'iso_alpha'],
#       dtype='object')

# %%
px.scatter(df, x= "Totalcases/1M", y="TotalDeath/1M", color="Country")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##  Geographic Visualization using Choropleth maps

# %%
# A choropleth map displays divided geographical areas or regions that are coloured, shaded or patterned in relation to a data variable.
#Amazing Representation of data in a map . Choropleth maps provide an easy way to visualize how a measurement varies across a geographic area.

#Dataset 1
#parameters= dataset, locations= ISOALPHA, color, hover_name, color_continuous_scale= [RdYlGn, Blues, Viridis...],
#

# %%
df.columns
# Out:
# Index(['S.no', 'Country', 'TotalCases', 'TotalDeaths', 'Total Recovered',
#        'Active cases', 'Totalcases/1M', 'TotalDeath/1M', 'iso_alpha'],
#       dtype='object')

# %%
px.choropleth(df, locations = "iso_alpha", hover_name = "Country", color = "TotalDeath/1M", projection = "orthographic", color_continuous_scale = "Viridis")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.choropleth(df, locations = "iso_alpha", hover_name = "Country", color = "TotalDeath/1M", scope = "asia", color_continuous_scale = "Viridis")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##  Importing and Analyzing the dataset(Dataset 2: Covid-19 Pre-existing condition Medical dataset; source: CDC,US)

# %%
df1 = pd.read_csv("US_medical_data.csv")

# %%
df1
# Out:
#       Data as of Start Week  End Week State       Condition Group  \
# 0      1/10/2021   1/4/2020  1/9/2021    US  Respiratory diseases
# 1      1/10/2021   1/4/2020  1/9/2021    US  Respiratory diseases
# 2      1/10/2021   1/4/2020  1/9/2021    US  Respiratory diseases
# 3      1/10/2021   1/4/2020  1/9/2021    US  Respiratory diseases
# 4      1/10/2021   1/4/2020  1/9/2021    US  Respiratory diseases
# ...          ...        ...       ...   ...                   ...
# 12415  1/10/2021   1/4/2020  1/9/2021    PR              COVID-19
# 12416  1/10/2021   1/4/2020  1/9/2021    PR              COVID-19
# 12417  1/10/2021   1/4/2020  1/9/2021    PR              COVID-19
# 12418  1/10/2021   1/4/2020  1/9/2021    PR              COVID-19
# 12419  1/10/2021   1/4/2020  1/9/2021    PR              COVID-19
#
#                      Condition ICD10_codes   Age Group  COVID-19 Deaths  \
# 0      Influenza and pneumonia     J09-J18        0-24            198.0
# ...

# %%
df1.groupby(['State']).count()
# Out:
#        Data as of  Start Week  End Week  Condition Group  Condition  \
# State
# AK            230         230       230              230        230
# AL            230         230       230              230        230
# AR            230         230       230              230        230
# AZ            230         230       230              230        230
# CA            230         230       230              230        230
# CO            230         230       230              230        230
# CT            230         230       230              230        230
# DC            230         230       230              230        230
# DE            230         230       230              230        230
# FL            230         230       230              230        230
# GA            230         230       230              230        230
# HI            230         230       230              230        230
# IA            230         230       230              230        230
# ...

# %%
df1.groupby(['Condition Group']).count()
# Out:
#                                                     Data as of  Start Week  \
# Condition Group
# All other conditions and causes (residual)                 540         540
# Alzheimer disease                                          540         540
# COVID-19                                                   540         540
# Circulatory diseases                                      3780        3780
# Diabetes                                                   540         540
# Intentional and unintentional injury, poisoning...         540         540
# Malignant neoplasms                                        540         540
# Obesity                                                    540         540
# Renal failure                                              540         540
# Respiratory diseases                                      3240        3240
# Sepsis                                                     540         540
# ...

# %%
    df1.groupby(['Condition']).count()
# Out:
#                                                     Data as of  Start Week  \
# Condition
# Adult respiratory distress syndrome                        540         540
# All other conditions and causes (residual)                 540         540
# Alzheimer disease                                          540         540
# COVID-19                                                   540         540
# Cardiac arrest                                             540         540
# Cardiac arrhythmia                                         540         540
# Cerebrovascular diseases                                   540         540
# Chronic lower respiratory diseases                         540         540
# Diabetes                                                   540         540
# Heart failure                                              540         540
# Hypertensive diseases                                      540         540
# ...

# %%
    df1.groupby(['Age Group']).count()
# Out:
#             Data as of  Start Week  End Week  State  Condition Group  \
# Age Group
# 0-24              1242        1242      1242   1242             1242
# 25-34             1242        1242      1242   1242             1242
# 35-44             1242        1242      1242   1242             1242
# 45-54             1242        1242      1242   1242             1242
# 55-64             1242        1242      1242   1242             1242
# 65-74             1242        1242      1242   1242             1242
# 75-84             1242        1242      1242   1242             1242
# 85+               1242        1242      1242   1242             1242
# All Ages          1242        1242      1242   1242             1242
# Not stated        1242        1242      1242   1242             1242
#
#             Condition  ICD10_codes  COVID-19 Deaths  Number of Mentions  Flag
# Age Group
# 0-24             1242         1242              804                 812   438
# ...

# %% [markdown]
# ##  Visualizing the Pre-existing condition Medical dataset

# %%
#we are going to create a filter

filter1 = df1[(df1['State']== 'US')]

# %%
px.bar(df1, x = 'Age Group', y= 'COVID-19 Deaths', color = 'Condition', hover_name = 'Condition', log_y=True) # log_y=True is for better visualization
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(df1, x = 'Age Group', y= 'COVID-19 Deaths', color = 'Condition', hover_name = 'Condition', log_y=True) # log_y=True is for better visualization
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(filter1, x = 'Age Group', y= 'COVID-19 Deaths', color = 'Condition Group', hover_name = 'Condition') # log_y=True is for better visualization
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
